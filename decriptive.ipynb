# %%
import pandas as pd
import datetime
import seaborn as se
from matplotlib import pyplot as plt
import numpy as np

# %%
tweets=pd.read_json('C:\\Users\\YP\\Desktop\\Dedup2.json')

# %%
ab2021=tweets["created_at"]>'2021-01-01 00:00:00+00:00'# Tweets auf 2021 eingrenzen

# %%
Tweets=tweets[ab2021]

# %%
Tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33434 entries, 0 to 319475
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              33434 non-null  int64
#  1   author_id       33434 non-null  int64
#  2   created_at      33434 non-null  datetime64[ns, UTC]
#  3   text            33434 non-null  object
#  4   retweet_count   33434 non-null  float64
#  5   reply_count     33434 non-null  float64
#  6   like_count      33434 non-null  float64
#  7   quote_count     33434 non-null  float64
#  8   ref_type        33434 non-null  object
#  9   ref_id          33434 non-null  float64
#  10  mentioned_user  33434 non-null  object
#  11  TW_Name         33434 non-null  object
#  12  Partei          33434 non-null  object
#  13  Farbe           33434 non-null  object
#  14  Name            33105 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(5), int64(2), object(7)
# ...

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33616 entries, 0 to 319477
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              33616 non-null  int64
#  1   author_id       33616 non-null  int64
#  2   created_at      33616 non-null  datetime64[ns, UTC]
#  3   text            33616 non-null  object
#  4   retweet_count   33616 non-null  float64
#  5   reply_count     33616 non-null  float64
#  6   like_count      33616 non-null  float64
#  7   quote_count     33616 non-null  float64
#  8   ref_type        33616 non-null  object
#  9   ref_id          33616 non-null  float64
#  10  mentioned_user  33616 non-null  object
#  11  TW_Name         33616 non-null  object
#  12  Partei          33616 non-null  object
#  13  Farbe           33616 non-null  object
#  14  Name            33285 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(5), int64(2), object(7)
# ...

# %%
Tweets["Partei"].value_counts()
# Out:
# CDU/CSU                  10774
# Bündnis 90/Die Grünen     7116
# Die Linke                 4960
# AfD                       3983
# FDP                       3589
# SPD                       2814
# Fraktionslos               198
# Name: Partei, dtype: int64

# %%
se.set()#standardmäßige Seaborn Design
se.catplot(y= "Partei", data=Tweets,kind="count",palette=['#000000',"#ffff00","#800080","#808080","#00ffff","#008000","#ff0000"])
plt.xlabel("Anzahl Tweets")
#Welche Partei Tweetet wie viel
# Out:
# Text(0.5, 8.95999999999998, 'Anzahl Tweets')

# %%
Grunen=Tweets[Tweets.Partei=='Bündnis 90/Die Grünen']#MEnge der Tweets je Partei

# %%
AFD=Tweets[Tweets.Partei=='AfD']

# %%
SPD=Tweets[Tweets.Partei=='SPD']

# %%
Linke=Tweets[Tweets.Partei=='Die Linke']

# %%
FDP=Tweets[Tweets.Partei=='FDP']

# %%
CDU=Tweets[Tweets.Partei=='CDU/CSU']

# %%
sonst=Tweets[Tweets.Partei=='Fraktionslos']

# %%
se.catplot(y="Name",data=AFD, kind='count',color="#00ffff").set(title='In Twitter aktive Politiker der AfD')
plt.xlabel("Anzahl Tweets")
# Out:
# Text(0.5, 8.95999999999998, 'Anzahl Tweets')

# %%
se.catplot(y="Name", data=Grunen,kind='count', color="#008000").set(title='In Twitter aktive Politiker der Grünen')
plt.xlabel("Anzahl Tweets")
# Out:
# Text(0.5, 8.95999999999998, 'Anzahl Tweets')

# %%
se.catplot(y="Name", data=SPD,kind='count', color="#ff0000").set(title='In Twitter aktive Politiker der SPD')
plt.xlabel("Anzahl Tweets")
# Out:
# Text(0.5, 8.95999999999998, 'Anzahl Tweets')

# %%
se.catplot(y="Name", data=FDP,kind='count', color="#ffff00").set(title='In Twitter aktive Politiker der FDP')
plt.xlabel("Anzahl Tweets")
# Out:
# Text(0.5, 8.95999999999998, 'Anzahl Tweets')

# %%
se.catplot(y="Name",data=Linke, kind='count',color="#800080").set(title='In Twitter aktive Politiker der Linken')
plt.xlabel("Anzahl Tweets")
# Out:
# Text(0.5, 8.95999999999998, 'Anzahl Tweets')

# %%
se.catplot(y="Name",data=CDU, kind='count',color='#000000').set(title='In Twitter aktive Politiker der CDU/CSU')
plt.xlabel("Anzahl Tweets")
# Out:
# Text(0.5, 8.95999999999998, 'Anzahl Tweets')

# %%
se.catplot(y="Name",data=sonst, kind='count',color="#808080").set(title='In Twitter aktive Politiker ohne Partei')
plt.xlabel("Anzahl Tweets")
# Out:
# Text(0.5, 8.95999999999998, 'Anzahl Tweets')

# %%
meistgeRetweetTweet=Tweets["retweet_count"]>100000 #Tweets die am häufigsten geretweetet wurden

# %%
meisteRetwTweet=Tweets[meistgeRetweetTweet].sort_values("retweet_count")

# %%
se.barplot(x="retweet_count", y="Name", data=meisteRetwTweet,palette=['#008000','#008000','#008000',"#800080"] ).set(title= "Maximalanzahl der Retweets")
plt.xlabel("Anzahl Re-Tweets")
#Politiker dessen Tweet absolut die meisten Retweets bekamen
# Out:
# Text(0.5, 0, 'Anzahl Re-Tweets')

# %%
meisteRetwTweet[['text','retweet_count','Partei','Name']]
# Out:
#                                                      text  retweet_count  \
# 21674   RT @RayRedacted: People who broke into the Cap...       105542.0
# 18518   RT @JFennellAuthor: Greta Thunberg waiting in ...       127164.0
# 38000   RT @GretaThunberg: He seems like a very happy ...       146116.0
# 313497  RT @BernieSanders: Some people ask: Why would ...       156525.0
#
#                        Partei              Name
# 21674   Bündnis 90/Die Grünen    Künast, Renate
# 18518   Bündnis 90/Die Grünen     Lang, Ricarda
# 38000   Bündnis 90/Die Grünen     Lehmann, Sven
# 313497              Die Linke  Riexinger, Bernd

# %%
Tweets.Name.unique()
# Out:
# array(['Röttgen, Dr. Norbert', 'Theurer, Michael', 'Movassat, Niema',
#        'Petry, Dr. Frauke', 'Pretzell, Marcus', 'Lang, Ricarda',
#        'Künast, Renate', 'Pasemann, Frank', 'Klingbeil, Lars',
#        'Solms, Hermann Otto', 'Wanderwitz, Marco', 'Nouripour, Omid',
#        'Lehmann, Sven', 'Kindler, Sven-Christian', 'Schulz, Martin',
#        'Notz, Dr. Konstantin von', 'Schulz-Asche, Kordula',
#        'Suding, Katja', 'Özdemir, Cem', 'Wissing, Volker',
#        'Strengmann-Kuhn, Dr. Wolfgang', 'Luksic, Oliver', 'Ramelow, Bodo',
#        'Urbatsch, Marc', 'Körner, Moritz', 'Tauber, Dr. Peter',
#        'Maas, Heiko', 'Kühnert, Kevin', 'Steineke, Sebastian',
#        'Höcke, Björn', 'Kipping, Katja', 'Ziemiak, Paul',
#        'Klöckner, Julia', 'Spahn, Jens', 'Lauterbach, Dr. Karl',
#        'Scholz, Olaf', 'Nissen, Ulli', 'Stark-Watzinger, Bettina',
#        'Schipanski, Tankred', 'Schummer, Uwe', 'Kiesewetter, Roderich',
# ...

# %%
ohneNamen=Tweets["Name"].isnull()

# %%
Tweets[ohneNamen].Partei.value_counts()
# Out:
# CDU/CSU    329
# Name: Partei, dtype: int64

# %%
Weidel=Tweets["Name"]=='Weidel, Dr. Alice'

# %%
Tweets[Weidel]
# Out:
#                          id           author_id                created_at  \
# 310599  1380494482173521921  833398209053605888 2021-04-09 12:15:07+00:00
# 310600  1380111156082278403  833398209053605888 2021-04-08 10:51:55+00:00
# 310601  1379375364703653888  833398209053605888 2021-04-06 10:08:09+00:00
# 310602  1379067165685469184  833398209053605888 2021-04-05 13:43:28+00:00
# 310603  1378629986979082248  833398209053605888 2021-04-04 08:46:17+00:00
# ...                     ...                 ...                       ...
# 310692  1346448240481345541  833398209053605888 2021-01-05 13:27:30+00:00
# 310693  1346396611770011648  833398209053605888 2021-01-05 10:02:21+00:00
# 310694  1346126157155020801  833398209053605888 2021-01-04 16:07:40+00:00
# 310695  1346032867793580032  833398209053605888 2021-01-04 09:56:58+00:00
# 310696  1345335892358131713  833398209053605888 2021-01-02 11:47:26+00:00
#
#                                                      text  retweet_count  \
# ...

# %%
Tweets[CSU].mentioned_user.value_counts()
# Out:
# []                                                123
# ['hahnflo']                                        24
# ['VolkerUllrich']                                  19
# ['smuellermdb']                                    17
# ['TErndl']                                         16
#                                                  ...
# ['petertauber']                                     1
# ['VolkerUllrich', 'ArminLaschet']                   1
# ['SilberhornMdB', 'csu_bt', 'jensstoltenberg']      1
# ['st_lange', 'csu_bt']                              1
# ['smuellermdb', 'POTUS']                            1
# Name: mentioned_user, Length: 87, dtype: int64

# %%
se.catplot( y='mentioned_user',kind='count', data=Tweets[CSU])
# Out:
# C:\Users\YP\anaconda3\envs\consprojUmgeb\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self.fig.tight_layout(*args, **kwargs)
